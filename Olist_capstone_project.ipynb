# %%
# import the relevant libraries
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency
from sklearn.metrics import r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import PolynomialFeatures
from tabulate import tabulate
from statsmodels.tools import add_constant

# %%
# Load the data 
customer_info = pd.read_csv('customer_info.csv')
customer_info. head()
# Out:
#                         customer_id       customer_unique_id(barcode)  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    postal_code                   city state
# 0        14409                 franca    SP
# 1         9790  sao bernardo do campo    SP
# 2         1151              sao paulo    SP
# 3         8775        mogi das cruzes    SP
# 4        13056               campinas    SP

# %%
# Load the data 
product_info = pd.read_csv('product_info.csv')
product_info. head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
# Load the data 
employee_info = pd.read_csv('employee_info.csv')
employee_info. head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
# Load the data 
invoice_product_info = pd.read_csv('invoice_products_info.csv')
invoice_product_info. head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0     2017-09-19 9:45   58.90          13.29
# 1    2017-05-03 11:05  239.90          19.93
# 2    2018-01-18 14:48  199.00          17.87
# 3    2018-08-15 10:10   12.99          12.79
# 4    2017-02-13 13:57  199.90          18.14

# %%
# Load the data 
invoice_payment_info = pd.read_csv('invoice_payment_info.csv')
invoice_payment_info. head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# Load the data 
invoice_porducts_status= pd.read_csv('invoice_porducts_status.csv')
invoice_porducts_status. head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered         2017-10-02 10:56  2017-10-02 11:07
# 1    delivered         2018-07-24 20:41   2018-07-26 3:24
# 2    delivered          2018-08-08 8:38   2018-08-08 8:55
# 3    delivered         2017-11-18 19:28  2017-11-18 19:45
# 4    delivered         2018-02-13 21:18  2018-02-13 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             2017-10-04 19:55              2017-10-10 21:25
# 1             2018-07-26 14:31              2018-08-07 15:27
# 2             2018-08-08 13:50              2018-08-17 18:06
# 3             2017-11-22 13:39               2017-12-02 0:28
# 4             2018-02-14 19:46              2018-02-16 18:17
#
#   order_estimated_delivery_date
# 0               2017-10-18 0:00
# 1               2018-08-13 0:00
# 2               2018-09-04 0:00
# 3               2017-12-15 0:00
# 4               2018-02-26 0:00

# %%
# Load the data 
invoice_reviews= pd.read_csv('invoice_reviews.csv')
invoice_reviews. head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN      2018-01-18 0:00
# 1                                                NaN      2018-03-10 0:00
# 2                                                NaN      2018-02-17 0:00
# 3              Recebi bem antes do prazo estipulado.      2017-04-21 0:00
# 4  Parabéns lojas lannister adorei comprar pela I...      2018-03-01 0:00
#
#   review_answer_timestamp
# 0        2018-01-18 21:46
# 1         2018-03-11 3:05
# 2        2018-02-18 14:36
# 3        2017-04-21 22:02
# 4        2018-03-02 10:26

# %%
df1 = pd.merge(invoice_product_info, invoice_payment_info, on='order_id')
df1.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.90          13.29                   1  credit_card
# 1    2017-05-03 11:05  239.90          19.93                   1  credit_card
# 2    2018-01-18 14:48  199.00          17.87                   1  credit_card
# 3    2018-08-15 10:10   12.99          12.79                   1  credit_card
# 4    2017-02-13 13:57  199.90          18.14                   1  credit_card
#
#    payment_installments  payment_value
# 0                     2          72.19
# 1                     3         259.83
# 2                     5         216.87
# 3                     2          25.78
# 4                     3         218.04

# %%
df2 = pd.merge(df1, invoice_porducts_status, on='order_id')
df2.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.90          13.29                   1  credit_card
# 1    2017-05-03 11:05  239.90          19.93                   1  credit_card
# 2    2018-01-18 14:48  199.00          17.87                   1  credit_card
# 3    2018-08-15 10:10   12.99          12.79                   1  credit_card
# 4    2017-02-13 13:57  199.90          18.14                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     2          72.19  3ce436f183e68e07877b285a838db11a
# 1                     3         259.83  f6dd3ec061db4e3987629fe6b26e5cce
# 2                     5         216.87  6489ae5e4333f3693df5ad4372dab6d3
# 3                     2          25.78  d4eb9395c8c0431ee92fce09860c5a06
# 4                     3         218.04  58dbd0b2d70206bf40e62cd34e84d795
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          2017-09-13 8:59   2017-09-13 9:45
# 1    delivered         2017-04-26 10:53  2017-04-26 11:05
# 2    delivered         2018-01-14 14:33  2018-01-14 14:48
# 3    delivered         2018-08-08 10:00  2018-08-08 10:10
# 4    delivered         2017-02-04 13:57  2017-02-04 14:10
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             2017-09-19 18:34              2017-09-20 23:43
# 1             2017-05-04 14:35              2017-05-12 16:04
# 2             2018-01-16 12:36              2018-01-22 13:19
# 3             2018-08-10 13:28              2018-08-14 13:32
# 4              2017-02-16 9:46              2017-03-01 16:42
#
#   order_estimated_delivery_date
# 0               2017-09-29 0:00
# 1               2017-05-15 0:00
# 2               2018-02-05 0:00
# 3               2018-08-20 0:00
# 4               2017-03-17 0:00

# %%
df3 = pd.merge(df2, invoice_reviews,  on='order_id')
df3.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.90          13.29                   1  credit_card
# 1    2017-05-03 11:05  239.90          19.93                   1  credit_card
# 2    2018-01-18 14:48  199.00          17.87                   1  credit_card
# 3    2018-08-15 10:10   12.99          12.79                   1  credit_card
# 4    2017-02-13 13:57  199.90          18.14                   1  credit_card
#
#    payment_installments  ...  order_approved_at order_delivered_carrier_date  \
# 0                     2  ...    2017-09-13 9:45             2017-09-19 18:34
# 1                     3  ...   2017-04-26 11:05             2017-05-04 14:35
# 2                     5  ...   2018-01-14 14:48             2018-01-16 12:36
# 3                     2  ...   2018-08-08 10:10             2018-08-10 13:28
# 4                     3  ...   2017-02-04 14:10              2017-02-16 9:46
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0              2017-09-20 23:43               2017-09-29 0:00
# 1              2017-05-12 16:04               2017-05-15 0:00
# 2              2018-01-22 13:19               2018-02-05 0:00
# 3              2018-08-14 13:32               2018-08-20 0:00
# 4              2017-03-01 16:42               2017-03-17 0:00
#
#                           review_id review_score review_comment_title  \
# 0  97ca439bc427b48bc1cd7177abe71365            5                  NaN
# 1  7b07bacd811c4117b742569b04ce3580            4                  NaN
# 2  0c5b33dea94867d1ac402749e5438e8b            5                  NaN
# 3  f4028d019cb58564807486a6aaf33817            4                  NaN
# 4  940144190dcba6351888cafa43f3a3a5            5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.      2017-09-21 0:00
# 1                                                NaN      2017-05-13 0:00
# 2  Chegou antes do prazo previsto e o produto sur...      2018-01-23 0:00
# 3                                                NaN      2018-08-15 0:00
# 4            Gostei pois veio no prazo determinado .      2017-03-02 0:00
#
#    review_answer_timestamp
# 0         2017-09-22 10:57
# 1         2017-05-15 11:34
# 2         2018-01-23 16:06
# 3         2018-08-15 16:39
# 4         2017-03-03 10:54
#
# [5 rows x 24 columns]

# %%
df4 = pd.merge(df3, customer_info,  on='customer_id')
df4.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.90          13.29                   1  credit_card
# 1    2017-05-03 11:05  239.90          19.93                   1  credit_card
# 2    2018-01-18 14:48  199.00          17.87                   1  credit_card
# 3    2018-08-15 10:10   12.99          12.79                   1  credit_card
# 4    2017-02-13 13:57  199.90          18.14                   1  credit_card
#
#    payment_installments  ...                         review_id review_score  \
# 0                     2  ...  97ca439bc427b48bc1cd7177abe71365            5
# 1                     3  ...  7b07bacd811c4117b742569b04ce3580            4
# 2                     5  ...  0c5b33dea94867d1ac402749e5438e8b            5
# 3                     2  ...  f4028d019cb58564807486a6aaf33817            4
# 4                     3  ...  940144190dcba6351888cafa43f3a3a5            5
#
#   review_comment_title                             review_comment_message  \
# 0                  NaN     Perfeito, produto entregue antes do combinado.
# 1                  NaN                                                NaN
# 2                  NaN  Chegou antes do prazo previsto e o produto sur...
# 3                  NaN                                                NaN
# 4                  NaN            Gostei pois veio no prazo determinado .
#
#   review_creation_date review_answer_timestamp  \
# 0      2017-09-21 0:00        2017-09-22 10:57
# 1      2017-05-13 0:00        2017-05-15 11:34
# 2      2018-01-23 0:00        2018-01-23 16:06
# 3      2018-08-15 0:00        2018-08-15 16:39
# 4      2017-03-02 0:00        2017-03-03 10:54
#
#         customer_unique_id(barcode) postal_code                   city  state
# 0  871766c5855e863f6eccc05f988b23cb       28013  campos dos goytacazes     RJ
# 1  eb28e67c4c0b83846050ddfb8a35d051       15775        santa fe do sul     SP
# 2  3818d81c6709e39d06b2738a8d3a2474       35661          para de minas     MG
# 3  af861d436cfc08b2c2ddefd0ba074622       12952                atibaia     SP
# 4  64b576fb70d441e8f1b2d7d446e483c5       13226        varzea paulista     SP
#
# [5 rows x 28 columns]

# %%
df5 = pd.merge(df4, product_info,  on='product_id')
df5.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#   shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.9          13.29                   1  credit_card
# 1     2017-07-05 2:44   55.9          17.96                   1       boleto
# 2    2018-05-23 10:56   64.9          18.33                   1  credit_card
# 3    2017-08-07 18:55   58.9          16.17                   1  credit_card
# 4    2017-08-16 22:05   58.9          13.29                   1  credit_card
#
#    payment_installments  ...                   city state  \
# 0                     2  ...  campos dos goytacazes    RJ
# 1                     1  ...                  jatai    GO
# 2                     2  ...         belo horizonte    MG
# 3                     3  ...   sao jose dos pinhais    PR
# 4                     4  ...   conselheiro lafaiete    MG
#
#   product_category_name product_name_lenght product_description_lenght  \
# 0            cool_stuff                58.0                      598.0
# 1            cool_stuff                58.0                      598.0
# 2            cool_stuff                58.0                      598.0
# 3            cool_stuff                58.0                      598.0
# 4            cool_stuff                58.0                      598.0
#
#   product_photos_qty product_weight_g product_length_cm product_height_cm  \
# 0                4.0            650.0              28.0               9.0
# 1                4.0            650.0              28.0               9.0
# 2                4.0            650.0              28.0               9.0
# 3                4.0            650.0              28.0               9.0
# 4                4.0            650.0              28.0               9.0
#
#    product_width_cm
# 0              14.0
# 1              14.0
# 2              14.0
# 3              14.0
# 4              14.0
#
# [5 rows x 36 columns]

# %%
df6 = pd.merge(df5, employee_info,  on='seller_id')
df6.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#   shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0     2017-09-19 9:45   58.9          13.29                   1  credit_card
# 1     2017-07-05 2:44   55.9          17.96                   1       boleto
# 2    2018-05-23 10:56   64.9          18.33                   1  credit_card
# 3    2017-08-07 18:55   58.9          16.17                   1  credit_card
# 4    2017-08-16 22:05   58.9          13.29                   1  credit_card
#
#    payment_installments  ...  product_name_lenght product_description_lenght  \
# 0                     2  ...                 58.0                      598.0
# 1                     1  ...                 58.0                      598.0
# 2                     2  ...                 58.0                      598.0
# 3                     3  ...                 58.0                      598.0
# 4                     4  ...                 58.0                      598.0
#
#   product_photos_qty product_weight_g product_length_cm product_height_cm  \
# 0                4.0            650.0              28.0               9.0
# 1                4.0            650.0              28.0               9.0
# 2                4.0            650.0              28.0               9.0
# 3                4.0            650.0              28.0               9.0
# 4                4.0            650.0              28.0               9.0
#
#   product_width_cm seller_zip_code_prefix    seller_city  seller_state
# 0             14.0                  27277  volta redonda            SP
# 1             14.0                  27277  volta redonda            SP
# 2             14.0                  27277  volta redonda            SP
# 3             14.0                  27277  volta redonda            SP
# 4             14.0                  27277  volta redonda            SP
#
# [5 rows x 39 columns]

# %%
df6.describe()
# Out:
#        order_item_id          price  freight_value  payment_sequential  \
# count  117329.000000  117329.000000  117329.000000       117329.000000
# mean        1.194121     120.524349      20.027514            1.094452
# std         0.684225     182.944843      15.828077            0.731174
# min         1.000000       0.850000       0.000000            1.000000
# 25%         1.000000      39.900000      13.080000            1.000000
# 50%         1.000000      74.900000      16.280000            1.000000
# 75%         1.000000     134.900000      21.180000            1.000000
# max        21.000000    6735.000000     409.680000           29.000000
#
#        payment_installments  payment_value   review_score    postal_code  \
# count         117329.000000  117329.000000  117329.000000  117329.000000
# mean               2.940151     172.062565       4.031467   35060.118112
# std                2.775370     265.388194       1.387927   29849.496175
# min                0.000000       0.000000       1.000000    1003.000000
# 25%                1.000000      60.750000       4.000000   11250.000000
# 50%                2.000000     108.100000       5.000000   24240.000000
# 75%                4.000000     189.060000       5.000000   58770.000000
# max               24.000000   13664.080000       5.000000   99990.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count        115634.000000               115634.000000       115634.000000
# mean             48.768018                  785.802861            2.205528
# std              10.033831                  652.382965            1.717783
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  346.000000            1.000000
# 50%              52.000000                  600.000000            1.000000
# 75%              57.000000                  983.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count     117309.000000      117309.000000      117309.000000
# mean        2110.763062          30.254456          16.612476
# std         3785.128931          16.177519          13.452625
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1800.000000          38.000000          20.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm  seller_zip_code_prefix
# count     117309.000000           117329.000000
# mean          23.071452            24450.781955
# std           11.745875            27582.364358
# min            6.000000             1001.000000
# 25%           15.000000             6429.000000
# 50%           20.000000            13660.000000
# 75%           30.000000            28035.000000
# max          118.000000            99730.000000

# %%
data_wireframe=df6.drop (['order_item_id','shipping_limit_date','payment_sequential',
                          'product_name_lenght','product_description_lenght','product_photos_qty'], axis=1)
data_wireframe
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       130898c0987d1801452a8ed92a670612  4244733e06e7ecb4970a6e2683c13e61
# 2       532ed5e14e24ae1f0d735b91524b98b9  4244733e06e7ecb4970a6e2683c13e61
# 3       6f8c31653edb8c83e1a739408b5ff750  4244733e06e7ecb4970a6e2683c13e61
# 4       7d19f4ef4d04461989632411b7e588b9  4244733e06e7ecb4970a6e2683c13e61
# ...                                  ...                               ...
# 117324  fecc4ea5a3e06ce3192ae2f05b7a8439  70adb75b3b2e86cffbb697c90867c3f3
# 117325  fecc4ea5a3e06ce3192ae2f05b7a8439  70adb75b3b2e86cffbb697c90867c3f3
# 117326  fecc4ea5a3e06ce3192ae2f05b7a8439  70adb75b3b2e86cffbb697c90867c3f3
# 117327  ff701a7c869ad21de22a6994237c8a00  5ff4076c0f01eeba4f728c9e3fa2653c
# 117328  ff701a7c869ad21de22a6994237c8a00  5ff4076c0f01eeba4f728c9e3fa2653c
#
#                                seller_id  price  freight_value payment_type  \
# 0       48436dade18ac8b2bce089ec2a041202   58.9          13.29  credit_card
# 1       48436dade18ac8b2bce089ec2a041202   55.9          17.96       boleto
# 2       48436dade18ac8b2bce089ec2a041202   64.9          18.33  credit_card
# 3       48436dade18ac8b2bce089ec2a041202   58.9          16.17  credit_card
# 4       48436dade18ac8b2bce089ec2a041202   58.9          13.29  credit_card
# ...                                  ...    ...            ...          ...
# 117324  4e2627090e6e5b9fabba883a37897683   39.9          14.10  credit_card
# 117325  4e2627090e6e5b9fabba883a37897683   39.9          14.10  credit_card
# 117326  4e2627090e6e5b9fabba883a37897683   39.9          14.10  credit_card
# 117327  3e35a8bb43569389d3cebef0ce820f69   27.9          14.44  credit_card
# 117328  3e35a8bb43569389d3cebef0ce820f69   27.9          14.44  credit_card
#
#         payment_installments  payment_value                       customer_id  \
# 0                          2          72.19  3ce436f183e68e07877b285a838db11a
# 1                          1          73.86  e6eecc5a77de221464d1c4eaff0a9b64
# 2                          2          83.23  4ef55bf80f711b372afebcb7c715344a
# 3                          3          75.07  30407a72ad8b3f4df4d15369126b20c9
# 4                          4          72.19  91a792fef70ecd8cc69d3c7feb3d12da
# ...                      ...            ...                               ...
# 117324                     1         216.00  ec43686dd7b2f48ea65475606fdfc85d
# 117325                     1         216.00  ec43686dd7b2f48ea65475606fdfc85d
# 117326                     1         216.00  ec43686dd7b2f48ea65475606fdfc85d
# 117327                     1          84.68  8f6d16c31abb30b7b4650272cb0014a3
# 117328                     1          84.68  8f6d16c31abb30b7b4650272cb0014a3
#
#        order_status  ...                   city state product_category_name  \
# 0         delivered  ...  campos dos goytacazes    RJ            cool_stuff
# 1         delivered  ...                  jatai    GO            cool_stuff
# 2         delivered  ...         belo horizonte    MG            cool_stuff
# 3         delivered  ...   sao jose dos pinhais    PR            cool_stuff
# 4         delivered  ...   conselheiro lafaiete    MG            cool_stuff
# ...             ...  ...                    ...   ...                   ...
# 117324   processing  ...                jundiai    SP      moveis_decoracao
# 117325   processing  ...                jundiai    SP      moveis_decoracao
# 117326   processing  ...                jundiai    SP      moveis_decoracao
# 117327    delivered  ...               cacapava    SP               bebidas
# 117328    delivered  ...               cacapava    SP               bebidas
#
#        product_weight_g product_length_cm product_height_cm  product_width_cm  \
# 0                 650.0              28.0               9.0              14.0
# 1                 650.0              28.0               9.0              14.0
# 2                 650.0              28.0               9.0              14.0
# 3                 650.0              28.0               9.0              14.0
# 4                 650.0              28.0               9.0              14.0
# ...                 ...               ...               ...               ...
# 117324            100.0              65.0              11.0              11.0
# 117325            100.0              65.0              11.0              11.0
# 117326            100.0              65.0              11.0              11.0
# 117327           2000.0              19.0              38.0              19.0
# 117328           2000.0              19.0              38.0              19.0
#
#        seller_zip_code_prefix     seller_city seller_state
# 0                       27277   volta redonda           SP
# 1                       27277   volta redonda           SP
# 2                       27277   volta redonda           SP
# 3                       27277   volta redonda           SP
# 4                       27277   volta redonda           SP
# ...                       ...             ...          ...
# 117324                  31565  belo horizonte           MG
# 117325                  31565  belo horizonte           MG
# 117326                  31565  belo horizonte           MG
# 117327                   3124       sao paulo           SP
# 117328                   3124       sao paulo           SP
#
# [117329 rows x 33 columns]

# %%
data_wireframe=df6.drop (['order_item_id','shipping_limit_date','payment_sequential',
                          'product_name_lenght','product_description_lenght','product_photos_qty',
                         'order_approved_at','order_delivered_carrier_date', 'order_delivered_customer_date',
       'order_estimated_delivery_date','review_comment_title','review_comment_message',
       'review_creation_date', 'review_answer_timestamp',
       'customer_unique_id(barcode)'], axis=1)
data_wireframe.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  130898c0987d1801452a8ed92a670612  4244733e06e7ecb4970a6e2683c13e61
# 2  532ed5e14e24ae1f0d735b91524b98b9  4244733e06e7ecb4970a6e2683c13e61
# 3  6f8c31653edb8c83e1a739408b5ff750  4244733e06e7ecb4970a6e2683c13e61
# 4  7d19f4ef4d04461989632411b7e588b9  4244733e06e7ecb4970a6e2683c13e61
#
#                           seller_id  price  freight_value payment_type  \
# 0  48436dade18ac8b2bce089ec2a041202   58.9          13.29  credit_card
# 1  48436dade18ac8b2bce089ec2a041202   55.9          17.96       boleto
# 2  48436dade18ac8b2bce089ec2a041202   64.9          18.33  credit_card
# 3  48436dade18ac8b2bce089ec2a041202   58.9          16.17  credit_card
# 4  48436dade18ac8b2bce089ec2a041202   58.9          13.29  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     2          72.19  3ce436f183e68e07877b285a838db11a
# 1                     1          73.86  e6eecc5a77de221464d1c4eaff0a9b64
# 2                     2          83.23  4ef55bf80f711b372afebcb7c715344a
# 3                     3          75.07  30407a72ad8b3f4df4d15369126b20c9
# 4                     4          72.19  91a792fef70ecd8cc69d3c7feb3d12da
#
#   order_status  ...                   city state  product_category_name  \
# 0    delivered  ...  campos dos goytacazes    RJ             cool_stuff
# 1    delivered  ...                  jatai    GO             cool_stuff
# 2    delivered  ...         belo horizonte    MG             cool_stuff
# 3    delivered  ...   sao jose dos pinhais    PR             cool_stuff
# 4    delivered  ...   conselheiro lafaiete    MG             cool_stuff
#
#    product_weight_g product_length_cm product_height_cm product_width_cm  \
# 0             650.0              28.0               9.0             14.0
# 1             650.0              28.0               9.0             14.0
# 2             650.0              28.0               9.0             14.0
# 3             650.0              28.0               9.0             14.0
# 4             650.0              28.0               9.0             14.0
#
#    seller_zip_code_prefix    seller_city  seller_state
# 0                   27277  volta redonda            SP
# 1                   27277  volta redonda            SP
# 2                   27277  volta redonda            SP
# 3                   27277  volta redonda            SP
# 4                   27277  volta redonda            SP
#
# [5 rows x 24 columns]

# %%
data_wireframe.columns
# Out:
# Index(['order_id', 'product_id', 'seller_id', 'price', 'freight_value',
#        'payment_type', 'payment_installments', 'payment_value', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'review_id', 'review_score',
#        'postal_code', 'city', 'state', 'product_category_name',
#        'product_weight_g', 'product_length_cm', 'product_height_cm',
#        'product_width_cm', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state'],
#       dtype='object')

# %%
data_wireframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  117329 non-null  object
#  1   product_id                117329 non-null  object
#  2   seller_id                 117329 non-null  object
#  3   price                     117329 non-null  float64
#  4   freight_value             117329 non-null  float64
#  5   payment_type              117329 non-null  object
#  6   payment_installments      117329 non-null  int64
#  7   payment_value             117329 non-null  float64
#  8   customer_id               117329 non-null  object
#  9   order_status              117329 non-null  object
#  10  order_purchase_timestamp  117329 non-null  object
#  11  review_id                 117329 non-null  object
#  12  review_score              117329 non-null  int64
#  13  postal_code               117329 non-null  int64
#  14  city                      117329 non-null  object
#  15  state                     117329 non-null  object
#  16  product_category_name     115634 non-null  object
#  17  product_weight_g          117309 non-null  float64
#  18  product_length_cm         117309 non-null  float64
#  19  product_height_cm         117309 non-null  float64
#  20  product_width_cm          117309 non-null  float64
#  21  seller_zip_code_prefix    117329 non-null  int64
#  22  seller_city               117329 non-null  object
#  23  seller_state              117329 non-null  object
# dtypes: float64(7), int64(4), object(13)
# memory usage: 22.4+ MB

# %%
df_without_cust_pro_emp_info=data_wireframe.drop([
       'postal_code', 'city', 'state', 'product_weight_g', 'product_length_cm', 'product_height_cm',
       'product_width_cm', 'seller_zip_code_prefix', 'seller_city',
       'seller_state'], axis=1)

# %%
product_info_final=product_info.drop(['product_name_lenght','product_description_lenght',
                                      'product_photos_qty'], axis=1)

# %%
customer_info_final=customer_info.drop(['customer_unique_id(barcode)'], axis=1)

# %%
employee_info_final=employee_info

# %%
df_without_cust_pro_emp_info.to_csv('df_without_cust_pro_emp_info.csv', index=False)

# %%
product_info_final.to_csv('product_info_final.csv', index=False)

# %%
customer_info_final.to_csv('customer_info_final.csv', index=False)
